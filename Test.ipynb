# %%
import pandas as pd
import altair
import csv 
import tkinter as tk 
CT1_t = 0
CT2_t = 0
CT3_t = 0
CT4_t = 0
C1_t = 0
C2_t = 0
C3_t = 0
C4_t = 0
C5_t = 0

def save_type (*arg):
    CT1_t = CheckTyp1.get()
    CT2_t = CheckTyp2.get()
    CT3_t = CheckTyp3.get()
    CT4_t = CheckTyp4.get()
    Typ.destroy()

def save_var (*arg):
    C1_t = CheckVar1.get()
    C2_t = CheckVar2.get()
    C3_t = CheckVar3.get()
    C4_t = CheckVar4.get()
    C5_t = CheckVar5.get()
    Var.destroy()
    
Typ = Tk()
Typ.title("Choisir le type de graphique")

cadre1 = Frame(Typ)
cadre1.pack()
cadre2 = Frame(Typ)
cadre2.pack()
bottomframe = Frame(Typ)
bottomframe.pack(side = BOTTOM)


CheckTyp1 = IntVar()
CheckTyp2 = IntVar()
CheckTyp3 = IntVar()
CheckTyp4 = IntVar()

txt1 = Label(cadre1, text="1 variable")
txt1.pack(side = TOP)
txt2 = Label(cadre2, text="2 variables")
txt2.pack (side = TOP)
CT1 = Checkbutton(cadre1, text = "Histogramme", variable = CheckTyp1, onvalue = 1, offvalue = 0, height=5, width = 20)
CT1.pack( side = LEFT)
CT2 = Checkbutton(cadre2, text = "Graph pirate", variable = CheckTyp2, onvalue = 1, offvalue = 0)
CT2.pack( side = RIGHT)
CT3 = Checkbutton (cadre1, text = "Nuage de points, 1 variable", variable = CheckTyp3, onvalue = 1, offvalue = 0)
CT3.pack( side = LEFT)
CT4 = Checkbutton (cadre2, text = "Nuage de points, 2 variables", variable = CheckTyp4, onvalue = 1, offvalue = 0)
CT4.pack( side = RIGHT)

buttonOkTyp = Button(bottomframe, text="Valider")
buttonOkTyp.pack() 
buttonOkTyp.bind('<Button-1>', save_type)

Typ.mainloop()

if CT2_t == 1 or CT4_t == 1:
    
    Var = Tk()
    Var.title("Choisir les variables à tester \(1\)")
    Check1Var1 = IntVar()
    Check1Var2 = IntVar()
    Check1Var3 = IntVar()
    Check1Var4 = IntVar()
    Check1Var5 = IntVar()
    C1 = Checkbutton(Var, text = "Tour", variable = Check1Var1, onvalue = 1, offvalue = 0)
    C1.pack()
    C2 = Checkbutton(Var, text = "Vidéo", variable = Check1Var2, onvalue = 1, offvalue = 0, height=5, width = 20)
    C2.pack()
    C3 = Checkbutton (Var, text = "Durée", variable = Check1Var3, onvalue = 1, offvalue = 0, height=5,width=20)
    C3.pack()
    C4 = Checkbutton (Var,text="Décile",variable=Check1Var4,onvalue=1,offvalue=0,height=5,width=20)
    C4.pack()
    C5=Checkbutton (Var,text="Quartile",variable=Check1Var5,onvalue=1,offvalue=0,height=5,width=20)
    C5.pack()

    buttonOkV1 = Button(Var, text="Valider")
    buttonOkV1.pack(side = BOTTOM)
    buttonOkV1.bind('<Button-1>', save_var)
    Var.mainloop()
    
    

else :
    Var2 = tk.Tk()
    Var2.title("Choisir les variables à tester \(2\)")
    Check2Var1 = tk.IntVar()
    Check2Var2 = tk.IntVar()
    Check2Var3 = tk.IntVar()
    Check2Var4 = tk.IntVar()
    Check2Var5 = tk.IntVar()
    C1V2 = tk.Checkbutton(Var2, text = "Tour", variable = Check2Var1, onvalue = 1, offvalue = 0, height=5, width = 20)
    C1V2.pack()
    C2V2 = tk.Checkbutton(Var2, text = "Vidéo", variable = Check2Var2, onvalue = 1, offvalue = 0, height=5, width = 20)
    C2V2.pack()
    C3V2 = tk.Checkbutton (Var2, text = "Durée", variable = Check2Var3, onvalue = 1, offvalue = 0, height=5,width=20)
    C3V2.pack()
    C4V2 = tk.Checkbutton (Var2,text="Décile",variable=Check2Var4,onvalue=1,offvalue=0,height=5,width=20)
    C4V2.pack()
    C5V2 =tk.Checkbutton (Var2,text="Quartile",variable=Check2Var5,onvalue=1,offvalue=0,height=5,width=20)
    C5V2.pack()

    buttonOkV2 = tk.Button(Var2, text="Valider")
    buttonOkV2.pack(side = BOTTOM) 
    buttonOkV2.bind('<Button-1>',  save_var)

    Var.mainloop()
